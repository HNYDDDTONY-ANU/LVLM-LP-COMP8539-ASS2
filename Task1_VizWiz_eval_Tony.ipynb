# %%
# Google Colab环境配置
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/COMP8539/assignment2/LVLM-LP
# !ls

# %%
# 检查transformers版本
import transformers
print(transformers.__file__)
print(transformers.__version__)

# %%
# CUDA设备检查
import torch
print("CUDA 可用:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU 数量:", torch.cuda.device_count())
    print("当前设备:", torch.cuda.current_device())
    print("设备名称:", torch.cuda.get_device_name(torch.cuda.current_device()))

# %%
# 原有导入保持不变
import os
import json

import numpy as np
from glob import glob
from tqdm.auto import tqdm
from sklearn.linear_model import LogisticRegression

from utils.func import read_data, softmax
from utils.metric import evaluate

# %%
model_name = "LLaVA-7B"
prompt = "oe"

# %%
_, x_train, y_train = read_data(model_name, "VizWiz", split="train", prompt=prompt, token_idx=0)
val_data, x_val, y_val = read_data(model_name, "VizWiz", split="val", prompt=prompt, token_idx=0, return_data=True)

print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 _, x_train, y_train = read_data(model_name, "VizWiz", split="train", prompt=prompt, token_idx=0)
#       2 val_data, x_val, y_val = read_data(model_name, "VizWiz", split="val", prompt=prompt, token_idx=0, return_data=True)
#       4 print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
#
# File f:\ANU\2025 - MCOMP - Year 1\h. S2 - COMP8539\c_Assessment\Assignment 2\LVLM-LP-COMP8539-ASS2\utils\func.py:56, in read_data(model, dataset, split, prompt, token_idx, return_data, num_samples)
#      53 def read_data(model, dataset, split="val", prompt='oe', token_idx=0, return_data=False, num_samples=None):
#      54     x, y = [], []
# ---> 56     with open(f"./output/{model}/{dataset}_{split}_{prompt}.jsonl") as f:
#      57         dataset = []
#      58         for line in tqdm(f):
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/LLaVA-7B/VizWiz_train_oe.jsonl'

# %%
if prompt == "oe":
    label_list = [ins['label'] for ins in val_data]
    val_labeled = json.load(open(f'./output/{model_name}/VizWiz_val_oe_labeled.json'))
    llava_pred = [0 if ins["is_answer"] == 'no' else 1 for ins in val_labeled]
    evaluate(label_list, llava_pred, show=True)

# %% [markdown]
# ### Direrctly check the responses

# %%
label_list = [ins['label'] for ins in val_data]
pred_list = [0 if "unanswerable" in ins['response'].lower() else 1 for ins in val_data]
evaluate(label_list, pred_list, show=True)

# %% [markdown]
# ### Use the probability of a spcific token

# %%
label_list = [ins['label'] for ins in val_data]
pred_list = 1 - softmax(x_val)[:, 853]
evaluate(label_list, pred_list, show=True)

# %% [markdown]
# ### Linear probing

# %%
model = LogisticRegression()
model.fit(x_train, y_train)

y_pred = model.predict_proba(x_val)[:, 1]
_, _, _, auroc = evaluate(y_val, y_pred, show=True)
